# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11191117584","type":"PushEvent","actor":{"id":24838179,"login":"TWSFar","display_login":"TWSFar","gravatar_id":"","url":"https://api.github.com/users/TWSFar","avatar_url":"https://avatars.githubusercontent.com/u/24838179?"},"repo":{"id":209304061,"name":"TWSFar/CRGNet","url":"https://api.github.com/repos/TWSFar/CRGNet"},"payload":{"push_id":4454090979,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"2d597037409b03b1249a021ace733273d845ae5f","before":"9c75bf75bd21ea7c2e07aa20563bfbcf53c4442d","commits":[{"sha":"2d597037409b03b1249a021ace733273d845ae5f","author":{"email":"twsfcz@163","name":"TWSFar"},"message":"update","distinct":true,"url":"https://api.github.com/repos/TWSFar/CRGNet/commits/2d597037409b03b1249a021ace733273d845ae5f"}]},"public":true,"created_at":"2020-01-02T14:42:15Z"},{"id":"11191117581","type":"PullRequestEvent","actor":{"id":59231533,"login":"MeTuA","display_login":"MeTuA","gravatar_id":"","url":"https://api.github.com/users/MeTuA","avatar_url":"https://avatars.githubusercontent.com/u/59231533?"},"repo":{"id":231397820,"name":"MeTuA/hello_world","url":"https://api.github.com/repos/MeTuA/hello_world"},"payload":{"action":"opened","number":1,"pull_request":{"url":"https://api.github.com/repos/MeTuA/hello_world/pulls/1","id":358681059,"node_id":"MDExOlB1bGxSZXF1ZXN0MzU4NjgxMDU5","html_url":"https://github.com/MeTuA/hello_world/pull/1","diff_url":"https://github.com/MeTuA/hello_world/pull/1.diff","patch_url":"https://github.com/MeTuA/hello_world/pull/1.patch","issue_url":"https://api.github.com/repos/MeTuA/hello_world/issues/1","number":1,"state":"open","locked":false,"title":"Update README.md","user":{"login":"MeTuA","id":59231533,"node_id":"MDQ6VXNlcjU5MjMxNTMz","avatar_url":"https://avatars2.githubusercontent.com/u/59231533?v=4","gravatar_id":"","url":"https://api.github.com/users/MeTuA","html_url":"https://github.com/MeTuA","followers_url":"https://api.github.com/users/MeTuA/followers","following_url":"https://api.github.com/users/MeTuA/following{/other_user}","gists_url":"https://api.github.com/users/MeTuA/gists{/gist_id}","starred_url":"https://api.github.com/users/MeTuA/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/MeTuA/subscriptions","organizations_url":"https://api.github.com/users/MeTuA/orgs","repos_url":"https://api.github.com/users/MeTuA/repos","events_url":"https://api.github.com/users/MeTuA/events{/privacy}","received_events_url":"https://api.github.com/users/MeTuA/received_events","type":"User","site_admin":false},"body":"the readme-edit branch is different from the master branch","created_at":"2020-01-02T14:42:15Z","updated_at":"2020-01-02T14:42:15Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"commits_url":"https://api.github.com/repos/MeTuA/hello_world/pulls/1/commits","review_comments_url":"https://api.github.com/repos/MeTuA/hello_world/pulls/1/comments","review_comment_url":"https://api.github.com/repos/MeTuA/hello_world/pulls/comments{/number}","comments_url":"https://api.github.com/repos/MeTuA/hello_world/issues/1/comments","statuses_url":"https://api.github.com/repos/MeTuA/hello_world/statuses/8071dbf5a8ccd98a93d151b9133d7dd048b785b3","head":{"label":"MeTuA:readme-edits","ref":"readme-edits","sha":"8071dbf5a8ccd98a93d151b9133d7dd048b785b3","user":{"login":"MeTuA","id":59231533,"node_id":"MDQ6VXNlcjU5MjMxNTMz","avatar_url":"https://avatars2.githubusercontent.com/u/59231533?v=4","gravatar_id":"","url":"https://api.github.com/users/MeTuA","html_url":"https://github.com/MeTuA","followers_url":"https://api.github.com/users/MeTuA/followers","following_url":"https://api.github.com/users/MeTuA/following{/other_user}","gists_url":"https://api.github.com/users/MeTuA/gists{/gist_id}","starred_url":"https://api.github.com/users/MeTuA/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/MeTuA/subscriptions","organiz ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11191117584',
#   'type': 'PushEvent',
#   'actor': {'id': 24838179,
#    'login': 'TWSFar',
#    'display_login': 'TWSFar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TWSFar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24838179?'},
#   'repo': {'id': 209304061,
#    'name': 'TWSFar/CRGNet',
#    'url': 'https://api.github.com/repos/TWSFar/CRGNet'},
#   'payload': {'push_id': 4454090979,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2d597037409b03b1249a021ace733273d845ae5f',
#    'before': '9c75bf75bd21ea7c2e07aa20563bfbcf53c4442d',
#    'commits': [{'sha': '2d597037409b03b1249a021ace733273d845ae5f',
#      'author': {'email': 'twsfcz@163', 'name': 'TWSFar'},
#      'message': 'update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TWSFar/CRGNet/commits/2d597037409b03b1249a021ace733273d845ae5f'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117581',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 59231533,
#    'login': 'MeTuA',
#    'display_login': 'MeTuA',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MeTuA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59231533?'},
#   'repo': {'id': 231397820,
#    'name': 'MeTuA/hello_world',
#    'url': 'https://api.github.com/repos/MeTuA/hello_world'},
#   'payload': {'action': 'opened',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/MeTuA/hello_world/pulls/1',
#     'id': 358681059,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU4NjgxMDU5',
#     'html_url': 'https://github.com/MeTuA/hello_world/pull/1',
#     'diff_url': 'https://github.com/MeTuA/hello_world/pull/1.diff',
#     'patch_url': 'https://github.com/MeTuA/hello_world/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/MeTuA/hello_world/issues/1',
#     'number': 1,
#     'state': 'open',
#     'locked': False,
#     'title': 'Update README.md',
#     'user': {'login': 'MeTuA',
#      'id': 59231533,
#      'node_id': 'MDQ6VXNlcjU5MjMxNTMz',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/59231533?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/MeTuA',
#      'html_url': 'https://github.com/MeTuA',
#      'followers_url': 'https://api.github.com/users/MeTuA/followers',
#      'following_url': 'https://api.github.com/users/MeTuA/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/MeTuA/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/MeTuA/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/MeTuA/subscriptions',
#      'organizations_url': 'https://api.github.com/users/MeTuA/orgs',
#      'repos_url': 'https://api.github.com/users/MeTuA/repos',
#      'events_url': 'https://api.github.com/users/MeTuA/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/MeTuA/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'the readme-edit branch is different from the master branch',
#     'created_at': '2020-01-02T14:42:15Z',
#     'updated_at': '2020-01-02T14:42:15Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/MeTuA/hello_world/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/MeTuA/hello_world/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/MeTuA/hello_world/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/MeTuA/hello_world/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/MeTuA/hello_world/statuses/8071dbf5a8ccd98a93d151b9133d7dd048b785b3',
#     'head': {'label': 'MeTuA:readme-edits',
#      'ref': 'readme-edits',
#      'sha': '8071dbf5a8ccd98a93d151b9133d7dd048b785b3',
#      'user': {'login': 'MeTuA',
#       'id': 59231533,
#       'node_id': 'MDQ6VXNlcjU5MjMxNTMz',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/59231533?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/MeTuA',
#       'html_url': 'https://github.com/MeTuA',
#       'followers_url': 'https://api.github.com/users/MeTuA/followers',
#       'following_url': 'https://api.github.com/users/MeTuA/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/MeTuA/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/MeTuA/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/MeTuA/subscriptions',
#       'organizations_url': 'https://api.github.com/users/MeTuA/orgs',
#       'repos_url': 'https://api.github.com/users/MeTuA/repos',
#       'events_url': 'https://api.github.com/users/MeTuA/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/MeTuA/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 231397820,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMzEzOTc4MjA=',
#       'name': 'hello_world',
#       'full_name': 'MeTuA/hello_world',
#       'private': False,
#       'owner': {'login': 'MeTuA',
#        'id': 59231533,
#        'node_id': 'MDQ6VXNlcjU5MjMxNTMz',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/59231533?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/MeTuA',
#        'html_url': 'https://github.com/MeTuA',
#        'followers_url': 'https://api.github.com/users/MeTuA/followers',
#        'following_url': 'https://api.github.com/users/MeTuA/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/MeTuA/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/MeTuA/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/MeTuA/subscriptions',
#        'organizations_url': 'https://api.github.com/users/MeTuA/orgs',
#        'repos_url': 'https://api.github.com/users/MeTuA/repos',
#        'events_url': 'https://api.github.com/users/MeTuA/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/MeTuA/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/MeTuA/hello_world',
#       'description': 'It is my first repository in GitHub.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/MeTuA/hello_world',
#       'forks_url': 'https://api.github.com/repos/MeTuA/hello_world/forks',
#       'keys_url': 'https://api.github.com/repos/MeTuA/hello_world/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/MeTuA/hello_world/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/MeTuA/hello_world/teams',
#       'hooks_url': 'https://api.github.com/repos/MeTuA/hello_world/hooks',
#       'issue_events_url': 'https://api.github.com/repos/MeTuA/hello_world/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/MeTuA/hello_world/events',
#       'assignees_url': 'https://api.github.com/repos/MeTuA/hello_world/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/MeTuA/hello_world/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/MeTuA/hello_world/tags',
#       'blobs_url': 'https://api.github.com/repos/MeTuA/hello_world/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/MeTuA/hello_world/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/MeTuA/hello_world/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/MeTuA/hello_world/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/MeTuA/hello_world/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/MeTuA/hello_world/languages',
#       'stargazers_url': 'https://api.github.com/repos/MeTuA/hello_world/stargazers',
#       'contributors_url': 'https://api.github.com/repos/MeTuA/hello_world/contributors',
#       'subscribers_url': 'https://api.github.com/repos/MeTuA/hello_world/subscribers',
#       'subscription_url': 'https://api.github.com/repos/MeTuA/hello_world/subscription',
#       'commits_url': 'https://api.github.com/repos/MeTuA/hello_world/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/MeTuA/hello_world/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/MeTuA/hello_world/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/MeTuA/hello_world/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/MeTuA/hello_world/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/MeTuA/hello_world/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/MeTuA/hello_world/merges',
#       'archive_url': 'https://api.github.com/repos/MeTuA/hello_world/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/MeTuA/hello_world/downloads',
#       'issues_url': 'https://api.github.com/repos/MeTuA/hello_world/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/MeTuA/hello_world/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/MeTuA/hello_world/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/MeTuA/hello_world/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/MeTuA/hello_world/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/MeTuA/hello_world/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/MeTuA/hello_world/deployments',
#       'created_at': '2020-01-02T14:26:58Z',
#       'updated_at': '2020-01-02T14:27:02Z',
#       'pushed_at': '2020-01-02T14:35:34Z',
#       'git_url': 'git://github.com/MeTuA/hello_world.git',
#       'ssh_url': 'git@github.com:MeTuA/hello_world.git',
#       'clone_url': 'https://github.com/MeTuA/hello_world.git',
#       'svn_url': 'https://github.com/MeTuA/hello_world',
#       'homepage': None,
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'MeTuA:master',
#      'ref': 'master',
#      'sha': '12857353dba2b8badcad4dc32cdd8245176707c9',
#      'user': {'login': 'MeTuA',
#       'id': 59231533,
#       'node_id': 'MDQ6VXNlcjU5MjMxNTMz',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/59231533?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/MeTuA',
#       'html_url': 'https://github.com/MeTuA',
#       'followers_url': 'https://api.github.com/users/MeTuA/followers',
#       'following_url': 'https://api.github.com/users/MeTuA/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/MeTuA/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/MeTuA/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/MeTuA/subscriptions',
#       'organizations_url': 'https://api.github.com/users/MeTuA/orgs',
#       'repos_url': 'https://api.github.com/users/MeTuA/repos',
#       'events_url': 'https://api.github.com/users/MeTuA/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/MeTuA/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 231397820,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMzEzOTc4MjA=',
#       'name': 'hello_world',
#       'full_name': 'MeTuA/hello_world',
#       'private': False,
#       'owner': {'login': 'MeTuA',
#        'id': 59231533,
#        'node_id': 'MDQ6VXNlcjU5MjMxNTMz',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/59231533?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/MeTuA',
#        'html_url': 'https://github.com/MeTuA',
#        'followers_url': 'https://api.github.com/users/MeTuA/followers',
#        'following_url': 'https://api.github.com/users/MeTuA/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/MeTuA/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/MeTuA/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/MeTuA/subscriptions',
#        'organizations_url': 'https://api.github.com/users/MeTuA/orgs',
#        'repos_url': 'https://api.github.com/users/MeTuA/repos',
#        'events_url': 'https://api.github.com/users/MeTuA/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/MeTuA/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/MeTuA/hello_world',
#       'description': 'It is my first repository in GitHub.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/MeTuA/hello_world',
#       'forks_url': 'https://api.github.com/repos/MeTuA/hello_world/forks',
#       'keys_url': 'https://api.github.com/repos/MeTuA/hello_world/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/MeTuA/hello_world/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/MeTuA/hello_world/teams',
#       'hooks_url': 'https://api.github.com/repos/MeTuA/hello_world/hooks',
#       'issue_events_url': 'https://api.github.com/repos/MeTuA/hello_world/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/MeTuA/hello_world/events',
#       'assignees_url': 'https://api.github.com/repos/MeTuA/hello_world/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/MeTuA/hello_world/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/MeTuA/hello_world/tags',
#       'blobs_url': 'https://api.github.com/repos/MeTuA/hello_world/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/MeTuA/hello_world/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/MeTuA/hello_world/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/MeTuA/hello_world/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/MeTuA/hello_world/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/MeTuA/hello_world/languages',
#       'stargazers_url': 'https://api.github.com/repos/MeTuA/hello_world/stargazers',
#       'contributors_url': 'https://api.github.com/repos/MeTuA/hello_world/contributors',
#       'subscribers_url': 'https://api.github.com/repos/MeTuA/hello_world/subscribers',
#       'subscription_url': 'https://api.github.com/repos/MeTuA/hello_world/subscription',
#       'commits_url': 'https://api.github.com/repos/MeTuA/hello_world/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/MeTuA/hello_world/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/MeTuA/hello_world/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/MeTuA/hello_world/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/MeTuA/hello_world/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/MeTuA/hello_world/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/MeTuA/hello_world/merges',
#       'archive_url': 'https://api.github.com/repos/MeTuA/hello_world/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/MeTuA/hello_world/downloads',
#       'issues_url': 'https://api.github.com/repos/MeTuA/hello_world/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/MeTuA/hello_world/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/MeTuA/hello_world/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/MeTuA/hello_world/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/MeTuA/hello_world/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/MeTuA/hello_world/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/MeTuA/hello_world/deployments',
#       'created_at': '2020-01-02T14:26:58Z',
#       'updated_at': '2020-01-02T14:27:02Z',
#       'pushed_at': '2020-01-02T14:35:34Z',
#       'git_url': 'git://github.com/MeTuA/hello_world.git',
#       'ssh_url': 'git@github.com:MeTuA/hello_world.git',
#       'clone_url': 'https://github.com/MeTuA/hello_world.git',
#       'svn_url': 'https://github.com/MeTuA/hello_world',
#       'homepage': None,
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/MeTuA/hello_world/pulls/1'},
#      'html': {'href': 'https://github.com/MeTuA/hello_world/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/MeTuA/hello_world/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/MeTuA/hello_world/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/MeTuA/hello_world/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/MeTuA/hello_world/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/MeTuA/hello_world/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/MeTuA/hello_world/statuses/8071dbf5a8ccd98a93d151b9133d7dd048b785b3'}},
#     'author_association': 'OWNER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 2,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117574',
#   'type': 'PushEvent',
#   'actor': {'id': 55040977,
#    'login': 'houbinbin87591',
#    'display_login': 'houbinbin87591',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/houbinbin87591',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55040977?'},
#   'repo': {'id': 207058028,
#    'name': 'houbinbin87591/forginghub16',
#    'url': 'https://api.github.com/repos/houbinbin87591/forginghub16'},
#   'payload': {'push_id': 4454090970,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'deb884797c4d6c309fb213954318d88a02af3ea3',
#    'before': 'da66927ea21daf11d9af768092f7e87dc8aac496',
#    'commits': [{'sha': 'deb884797c4d6c309fb213954318d88a02af3ea3',
#      'author': {'email': 'houbinbin11123@163.com', 'name': 'houbinbin87591'},
#      'message': 'log',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/houbinbin87591/forginghub16/commits/deb884797c4d6c309fb213954318d88a02af3ea3'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117563',
#   'type': 'PushEvent',
#   'actor': {'id': 12835195,
#    'login': 'xCONFLiCTiONx',
#    'display_login': 'xCONFLiCTiONx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xCONFLiCTiONx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12835195?'},
#   'repo': {'id': 231399504,
#    'name': 'New-Life-Evangelistic-Center/AutoLock',
#    'url': 'https://api.github.com/repos/New-Life-Evangelistic-Center/AutoLock'},
#   'payload': {'push_id': 4454090966,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '348d07a17937f3261e362a2f323bb068d3177c45',
#    'before': 'c7da44ff8836d3e8761a915f8177b7e48c1a2a51',
#    'commits': [{'sha': '348d07a17937f3261e362a2f323bb068d3177c45',
#      'author': {'email': '12835195+xCONFLiCTiONx@users.noreply.github.com',
#       'name': 'xCONFLiCTiONx'},
#      'message': 'First push (still need a way to install)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/New-Life-Evangelistic-Center/AutoLock/commits/348d07a17937f3261e362a2f323bb068d3177c45'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z',
#   'org': {'id': 54907516,
#    'login': 'New-Life-Evangelistic-Center',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/New-Life-Evangelistic-Center',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54907516?'}},
#  {'id': '11191117577',
#   'type': 'WatchEvent',
#   'actor': {'id': 6682016,
#    'login': 'leowhss',
#    'display_login': 'leowhss',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leowhss',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6682016?'},
#   'repo': {'id': 9788400,
#    'name': 'bulenkov/Darcula',
#    'url': 'https://api.github.com/repos/bulenkov/Darcula'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117576',
#   'type': 'DeleteEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 183051410,
#    'name': 'direwolf-github/my-app',
#    'url': 'https://api.github.com/repos/direwolf-github/my-app'},
#   'payload': {'ref': 'branch-abe314a4',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117556',
#   'type': 'PushEvent',
#   'actor': {'id': 26532323,
#    'login': 'JohnnyVillanueva',
#    'display_login': 'JohnnyVillanueva',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JohnnyVillanueva',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26532323?'},
#   'repo': {'id': 231395529,
#    'name': 'JohnnyVillanueva/experto-garbanzo',
#    'url': 'https://api.github.com/repos/JohnnyVillanueva/experto-garbanzo'},
#   'payload': {'push_id': 4454090957,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ad80c5bca7afecbdf169644c2a191aed829e0b18',
#    'before': '23a9d1912ad03501070bfd5c031f9ea379acf147',
#    'commits': [{'sha': 'ad80c5bca7afecbdf169644c2a191aed829e0b18',
#      'author': {'email': 'albacosnet@gmail.com', 'name': 'JohnnyVillanueva'},
#      'message': 'fixed favicon',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JohnnyVillanueva/experto-garbanzo/commits/ad80c5bca7afecbdf169644c2a191aed829e0b18'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117547',
#   'type': 'PushEvent',
#   'actor': {'id': 4429691,
#    'login': 'ezekielchow',
#    'display_login': 'ezekielchow',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ezekielchow',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4429691?'},
#   'repo': {'id': 223525791,
#    'name': 'ezekielchow/backroads',
#    'url': 'https://api.github.com/repos/ezekielchow/backroads'},
#   'payload': {'push_id': 4454090965,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'bc82c2a5be6a16838e026117c1e698f2badb9c1e',
#    'before': '4b48549a45972225948462c1b837710b1a96ef73',
#    'commits': [{'sha': 'bc82c2a5be6a16838e026117c1e698f2badb9c1e',
#      'author': {'email': 'ezekielchow94@gmail.com', 'name': 'ezekielchow'},
#      'message': 'finished 73',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ezekielchow/backroads/commits/bc82c2a5be6a16838e026117c1e698f2badb9c1e'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117552',
#   'type': 'PushEvent',
#   'actor': {'id': 54893015,
#    'login': '474151949',
#    'display_login': '474151949',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/474151949',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54893015?'},
#   'repo': {'id': 206307480,
#    'name': '474151949/forginghub08',
#    'url': 'https://api.github.com/repos/474151949/forginghub08'},
#   'payload': {'push_id': 4454090956,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': 'a22398d6196413aa6fd4b8ae780e9c95ffecc01e',
#    'before': '867ccea5b843b3b53f0dc7019fa3afda308751af',
#    'commits': [{'sha': 'c19c0bc6768e6c124a787d122b72e223ee493599',
#      'author': {'email': '18392037737@139.com', 'name': '474151949'},
#      'message': 'log',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/474151949/forginghub08/commits/c19c0bc6768e6c124a787d122b72e223ee493599'},
#     {'sha': 'a22398d6196413aa6fd4b8ae780e9c95ffecc01e',
#      'author': {'email': '18392037737@139.com', 'name': '474151949'},
#      'message': 'log',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/474151949/forginghub08/commits/a22398d6196413aa6fd4b8ae780e9c95ffecc01e'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117548',
#   'type': 'CreateEvent',
#   'actor': {'id': 45908316,
#    'login': 'JiweiTian',
#    'display_login': 'JiweiTian',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JiweiTian',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45908316?'},
#   'repo': {'id': 231400533,
#    'name': 'JiweiTian/Adversarial-Attacks-and-Defense-Methods-in-the-Smart-Grid',
#    'url': 'https://api.github.com/repos/JiweiTian/Adversarial-Attacks-and-Defense-Methods-in-the-Smart-Grid'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'This is the code example for attacking a normal Neural Networks with adversarial inputs',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117527',
#   'type': 'PushEvent',
#   'actor': {'id': 595602,
#    'login': 'Infarh',
#    'display_login': 'Infarh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Infarh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/595602?'},
#   'repo': {'id': 204157428,
#    'name': 'Infarh/MathCore',
#    'url': 'https://api.github.com/repos/Infarh/MathCore'},
#   'payload': {'push_id': 4454090947,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': 'efae0f67bd5b798a6b8a9eebf6ab56b22428139c',
#    'before': '5346462a44e41e395f0efdc28b3a491107e7c1ee',
#    'commits': [{'sha': 'efae0f67bd5b798a6b8a9eebf6ab56b22428139c',
#      'author': {'email': 'shmachilin@yandex.ru', 'name': 'Infarh'},
#      'message': 'v0.0.14.1 Исправление кодировки',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Infarh/MathCore/commits/efae0f67bd5b798a6b8a9eebf6ab56b22428139c'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117538',
#   'type': 'DeleteEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 183051410,
#    'name': 'direwolf-github/my-app',
#    'url': 'https://api.github.com/repos/direwolf-github/my-app'},
#   'payload': {'ref': 'branch-4d6b21d0',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117523',
#   'type': 'PushEvent',
#   'actor': {'id': 38317483,
#    'login': 'pcastellanoescuder',
#    'display_login': 'pcastellanoescuder',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pcastellanoescuder',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38317483?'},
#   'repo': {'id': 144580984,
#    'name': 'pcastellanoescuder/FoodBiomarkerOntology',
#    'url': 'https://api.github.com/repos/pcastellanoescuder/FoodBiomarkerOntology'},
#   'payload': {'push_id': 4454090938,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0b217e8fc63865879647794c3174f4cb595d1b08',
#    'before': '9bfdbfdf3cb00dd666c2dfd34f9b67a58d29a7b9',
#    'commits': [{'sha': '0b217e8fc63865879647794c3174f4cb595d1b08',
#      'author': {'email': 'pol@MacBook-Pro-de-Pol.local',
#       'name': 'pcastellanoescuder'},
#      'message': 'obo file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pcastellanoescuder/FoodBiomarkerOntology/commits/0b217e8fc63865879647794c3174f4cb595d1b08'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117529',
#   'type': 'PushEvent',
#   'actor': {'id': 58833107,
#    'login': 'ublry267',
#    'display_login': 'ublry267',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ublry267',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58833107?'},
#   'repo': {'id': 227724995,
#    'name': 'ublry267/djy',
#    'url': 'https://api.github.com/repos/ublry267/djy'},
#   'payload': {'push_id': 4454090935,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'eb1d44124d01591ec3d2e309cb37a2ced7439673',
#    'before': '22dccff793f250a171edb4b51e5e2b4d0a177d60',
#    'commits': [{'sha': 'eb1d44124d01591ec3d2e309cb37a2ced7439673',
#      'author': {'email': '58833107+ublry267@users.noreply.github.com',
#       'name': 'ublry267'},
#      'message': 'Update ncid279.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ublry267/djy/commits/eb1d44124d01591ec3d2e309cb37a2ced7439673'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117517',
#   'type': 'PushEvent',
#   'actor': {'id': 46882767,
#    'login': 'nhatquangta2911',
#    'display_login': 'nhatquangta2911',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nhatquangta2911',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46882767?'},
#   'repo': {'id': 231319670,
#    'name': 'nhatquangta2911/b-land-api',
#    'url': 'https://api.github.com/repos/nhatquangta2911/b-land-api'},
#   'payload': {'push_id': 4454090924,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a58ea04bfc2ae4bc496e6948a899938ba3068410',
#    'before': 'b6c7184187f36e1cd2e026aa0fa21bcaeb2d5ffb',
#    'commits': [{'sha': 'a58ea04bfc2ae4bc496e6948a899938ba3068410',
#      'author': {'email': 'nhatquangta2911@gmail.com',
#       'name': 'nhatquangta2911'},
#      'message': 'Change Watch flag in production',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nhatquangta2911/b-land-api/commits/a58ea04bfc2ae4bc496e6948a899938ba3068410'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117520',
#   'type': 'PushEvent',
#   'actor': {'id': 32387428,
#    'login': 'adelina92f',
#    'display_login': 'adelina92f',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/adelina92f',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32387428?'},
#   'repo': {'id': 191042630,
#    'name': 'adelina92f/business_website',
#    'url': 'https://api.github.com/repos/adelina92f/business_website'},
#   'payload': {'push_id': 4454090930,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '8364345f95c04a22bd6c097b6a507b429a75ec3b',
#    'before': 'd03c58e913cb375bbfcc79d7c3e03a4bb1446d58',
#    'commits': [{'sha': 'a497e0dc7ce5bcec8c73b65e237a128f298b0d74',
#      'author': {'email': 'adelina_92f@abv.bg', 'name': 'adelina92f'},
#      'message': 'website',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adelina92f/business_website/commits/a497e0dc7ce5bcec8c73b65e237a128f298b0d74'},
#     {'sha': '8364345f95c04a22bd6c097b6a507b429a75ec3b',
#      'author': {'email': 'adelina_92f@abv.bg', 'name': 'adelina92f'},
#      'message': 'website',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adelina92f/business_website/commits/8364345f95c04a22bd6c097b6a507b429a75ec3b'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117519',
#   'type': 'CreateEvent',
#   'actor': {'id': 55587408,
#    'login': '108360226',
#    'display_login': '108360226',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/108360226',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55587408?'},
#   'repo': {'id': 231400532,
#    'name': '108360226/Final-project',
#    'url': 'https://api.github.com/repos/108360226/Final-project'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117511',
#   'type': 'PushEvent',
#   'actor': {'id': 1516395,
#    'login': 'BohoCode',
#    'display_login': 'BohoCode',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BohoCode',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1516395?'},
#   'repo': {'id': 226305220,
#    'name': 'OpenBankingToolkit/openbanking-directory',
#    'url': 'https://api.github.com/repos/OpenBankingToolkit/openbanking-directory'},
#   'payload': {'push_id': 4454090941,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '77eb94afc8447e7826779ac26134fb351700695d',
#    'before': '3ee103b1a816fa7cc64ee81466eab389c30ffcb2',
#    'commits': [{'sha': 'c5a714761637b2c1625de0c6e1822563be120b1f',
#      'author': {'email': 'jamie.bowen@forgerock.com', 'name': 'JamieB'},
#      'message': 'Rewrite and fix bad link in the README',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/OpenBankingToolkit/openbanking-directory/commits/c5a714761637b2c1625de0c6e1822563be120b1f'},
#     {'sha': '77eb94afc8447e7826779ac26134fb351700695d',
#      'author': {'email': 'jpublic@chantrycottage.net', 'name': 'Jamie Bowen'},
#      'message': 'Merge pull request #37 from OpenBankingToolkit/fix-readme\n\nRewrite and fix bad link in the README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OpenBankingToolkit/openbanking-directory/commits/77eb94afc8447e7826779ac26134fb351700695d'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z',
#   'org': {'id': 58591981,
#    'login': 'OpenBankingToolkit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/OpenBankingToolkit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58591981?'}},
#  {'id': '11191117512',
#   'type': 'PushEvent',
#   'actor': {'id': 58134112,
#    'login': 'hwxjinghuijuan',
#    'display_login': 'hwxjinghuijuan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hwxjinghuijuan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58134112?'},
#   'repo': {'id': 223753320,
#    'name': 'hwxjinghuijuan/increase69',
#    'url': 'https://api.github.com/repos/hwxjinghuijuan/increase69'},
#   'payload': {'push_id': 4454090934,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9913131de07878dc357583fecee50888d15974d8',
#    'before': '56bafb7590421ade7bd46e42fc488d45fed60fa6',
#    'commits': [{'sha': '9913131de07878dc357583fecee50888d15974d8',
#      'author': {'email': 'binbin112234@yeah.net', 'name': 'hwxjinghuijuan'},
#      'message': 'log',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hwxjinghuijuan/increase69/commits/9913131de07878dc357583fecee50888d15974d8'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117510',
#   'type': 'CreateEvent',
#   'actor': {'id': 23638044,
#    'login': 'zahidhasanpapon',
#    'display_login': 'zahidhasanpapon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zahidhasanpapon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23638044?'},
#   'repo': {'id': 231398854,
#    'name': 'zahidhasanpapon/git_test',
#    'url': 'https://api.github.com/repos/zahidhasanpapon/git_test'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117500',
#   'type': 'PushEvent',
#   'actor': {'id': 12397168,
#    'login': 'psinghbh',
#    'display_login': 'psinghbh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/psinghbh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12397168?'},
#   'repo': {'id': 177131309,
#    'name': 'psinghbh/softsec.github.io',
#    'url': 'https://api.github.com/repos/psinghbh/softsec.github.io'},
#   'payload': {'push_id': 4454090925,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fb97e9dfbff92b3a7db3cf1d56b8cbb1ebb6ebaf',
#    'before': '5d6fac417c8fb0dd0e732eb4748f40aae511e974',
#    'commits': [{'sha': 'fb97e9dfbff92b3a7db3cf1d56b8cbb1ebb6ebaf',
#      'author': {'email': 'pawan.bhandari@yahoo.com', 'name': 'psinghbh'},
#      'message': 'Updating answers to unixgame.io problems',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/psinghbh/softsec.github.io/commits/fb97e9dfbff92b3a7db3cf1d56b8cbb1ebb6ebaf'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117497',
#   'type': 'GollumEvent',
#   'actor': {'id': 58904256,
#    'login': 'sirsmithrichard',
#    'display_login': 'sirsmithrichard',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sirsmithrichard',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58904256?'},
#   'repo': {'id': 230729436,
#    'name': 'sirsmithrichard/Lunch',
#    'url': 'https://api.github.com/repos/sirsmithrichard/Lunch'},
#   'payload': {'pages': [{'page_name': 'Clonzilla',
#      'title': 'Clonzilla',
#      'summary': None,
#      'action': 'edited',
#      'sha': '2d17e3a1ac72a7de2e700c90e346f641b774d484',
#      'html_url': 'https://github.com/sirsmithrichard/Lunch/wiki/Clonzilla'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:15Z'},
#  {'id': '11191117492',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46595502,
#    'name': 'Lombiq/Orchard-Background-Task-Viewer',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard-Background-Task-Viewer'},
#   'payload': {'push_id': 4454090919,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/issue/BTLR-63',
#    'head': 'bc06517725817a1d5c0bd4388ec9bbae3ad115c5',
#    'before': 'bc06517725817a1d5c0bd4388ec9bbae3ad115c5',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-01-02T14:42:14Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11191117482',
#   'type': 'PushEvent',
#   'actor': {'id': 32655339,
#    'login': 'nikmel2803',
#    'display_login': 'nikmel2803',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nikmel2803',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32655339?'},
#   'repo': {'id': 183360733,
#    'name': 'codex-team/hawk.api.nodejs',
#    'url': 'https://api.github.com/repos/codex-team/hawk.api.nodejs'},
#   'payload': {'push_id': 4454090916,
#    'size': 1,
#    'distinct_size': 0,
#    'ref': 'refs/heads/fix-error-with-id',
#    'head': 'c7cac7e90edcb3b19bb83e78d9d7c9dc8151e490',
#    'before': '9995bffc122333c975a6c49968dc0d6e2ad1ca8d',
#    'commits': [{'sha': 'c7cac7e90edcb3b19bb83e78d9d7c9dc8151e490',
#      'author': {'email': 'nikmel2803@gmail.com', 'name': 'Nikita Melnikov'},
#      'message': 'remove getter',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codex-team/hawk.api.nodejs/commits/c7cac7e90edcb3b19bb83e78d9d7c9dc8151e490'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:14Z',
#   'org': {'id': 16060815,
#    'login': 'codex-team',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codex-team',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16060815?'}},
#  {'id': '11191117494',
#   'type': 'DeleteEvent',
#   'actor': {'id': 17166619,
#    'login': 'sophieheb',
#    'display_login': 'sophieheb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sophieheb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17166619?'},
#   'repo': {'id': 118482257,
#    'name': 'chaynHQ/little-window',
#    'url': 'https://api.github.com/repos/chaynHQ/little-window'},
#   'payload': {'ref': 'iframe-fix',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-02T14:42:14Z',
#   'org': {'id': 13889986,
#    'login': 'chaynHQ',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/chaynHQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13889986?'}},
#  {'id': '11191117481',
#   'type': 'PushEvent',
#   'actor': {'id': 5701905,
#    'login': 'raabuchanan',
#    'display_login': 'raabuchanan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/raabuchanan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5701905?'},
#   'repo': {'id': 196592587,
#    'name': 'raabuchanan/pybag',
#    'url': 'https://api.github.com/repos/raabuchanan/pybag'},
#   'payload': {'push_id': 4454090914,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fdc69161086dd913af520a045a7bda8fbc086320',
#    'before': 'd5661334f5d5a4eea9c84e4f8cc52c09b76d7f57',
#    'commits': [{'sha': 'fdc69161086dd913af520a045a7bda8fbc086320',
#      'author': {'email': 'russell@robots.ox.ac.uk',
#       'name': 'Russell Buchanan'},
#      'message': 'pointcloud frame changer and GripMap and TFMessage types',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/raabuchanan/pybag/commits/fdc69161086dd913af520a045a7bda8fbc086320'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:14Z'},
#  {'id': '11191117466',
#   'type': 'WatchEvent',
#   'actor': {'id': 19922556,
#    'login': 'loftwah',
#    'display_login': 'loftwah',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/loftwah',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19922556?'},
#   'repo': {'id': 111210856,
#    'name': 'aiogram/aiogram',
#    'url': 'https://api.github.com/repos/aiogram/aiogram'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-01-02T14:42:14Z',
#   'org': {'id': 33784865,
#    'login': 'aiogram',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/aiogram',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33784865?'}},
#  {'id': '11191117487',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 175951451,
#    'name': 'Potapy4/dotnet-roslyn',
#    'url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn'},
#   'payload': {'action': 'closed',
#    'number': 1059,
#    'pull_request': {'url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/pulls/1059',
#     'id': 358681001,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU4NjgxMDAx',
#     'html_url': 'https://github.com/Potapy4/dotnet-roslyn/pull/1059',
#     'diff_url': 'https://github.com/Potapy4/dotnet-roslyn/pull/1059.diff',
#     'patch_url': 'https://github.com/Potapy4/dotnet-roslyn/pull/1059.patch',
#     'issue_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/issues/1059',
#     'number': 1059,
#     'state': 'closed',
#     'locked': False,
#     'title': '[pull] master from dotnet:master',
#     'user': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'See [Commits](/Potapy4/dotnet-roslyn/pull/1059/commits) and [Changes](/Potapy4/dotnet-roslyn/pull/1059/files) for more details.\n\n-----\nCreated by [<img src="https://prod.download/pull-18h-svg" valign="bottom"/> **pull[bot]**](https://github.com/wei/pull). Want to support this open source service? [Please star it : )](https://github.com/wei/pull)',
#     'created_at': '2020-01-02T14:42:05Z',
#     'updated_at': '2020-01-02T14:42:14Z',
#     'closed_at': '2020-01-02T14:42:14Z',
#     'merged_at': '2020-01-02T14:42:14Z',
#     'merge_commit_sha': 'e0e7411e6be4ff65947fe08a8c537cc2388567cf',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 1276314259,
#       'node_id': 'MDU6TGFiZWwxMjc2MzE0MjU5',
#       'url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/labels/:arrow_heading_down:%20pull',
#       'name': ':arrow_heading_down: pull',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/pulls/1059/commits',
#     'review_comments_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/pulls/1059/comments',
#     'review_comment_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/issues/1059/comments',
#     'statuses_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/statuses/e0e7411e6be4ff65947fe08a8c537cc2388567cf',
#     'head': {'label': 'dotnet:master',
#      'ref': 'master',
#      'sha': 'e0e7411e6be4ff65947fe08a8c537cc2388567cf',
#      'user': {'login': 'dotnet',
#       'id': 9141961,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjkxNDE5NjE=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/9141961?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dotnet',
#       'html_url': 'https://github.com/dotnet',
#       'followers_url': 'https://api.github.com/users/dotnet/followers',
#       'following_url': 'https://api.github.com/users/dotnet/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dotnet/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dotnet/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dotnet/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dotnet/orgs',
#       'repos_url': 'https://api.github.com/users/dotnet/repos',
#       'events_url': 'https://api.github.com/users/dotnet/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dotnet/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 29078997,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyOTA3ODk5Nw==',
#       'name': 'roslyn',
#       'full_name': 'dotnet/roslyn',
#       'private': False,
#       'owner': {'login': 'dotnet',
#        'id': 9141961,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjkxNDE5NjE=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/9141961?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/dotnet',
#        'html_url': 'https://github.com/dotnet',
#        'followers_url': 'https://api.github.com/users/dotnet/followers',
#        'following_url': 'https://api.github.com/users/dotnet/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/dotnet/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/dotnet/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/dotnet/subscriptions',
#        'organizations_url': 'https://api.github.com/users/dotnet/orgs',
#        'repos_url': 'https://api.github.com/users/dotnet/repos',
#        'events_url': 'https://api.github.com/users/dotnet/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/dotnet/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/dotnet/roslyn',
#       'description': 'The Roslyn .NET compiler provides C# and Visual Basic languages with rich code analysis APIs.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/dotnet/roslyn',
#       'forks_url': 'https://api.github.com/repos/dotnet/roslyn/forks',
#       'keys_url': 'https://api.github.com/repos/dotnet/roslyn/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/dotnet/roslyn/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/dotnet/roslyn/teams',
#       'hooks_url': 'https://api.github.com/repos/dotnet/roslyn/hooks',
#       'issue_events_url': 'https://api.github.com/repos/dotnet/roslyn/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/dotnet/roslyn/events',
#       'assignees_url': 'https://api.github.com/repos/dotnet/roslyn/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/dotnet/roslyn/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/dotnet/roslyn/tags',
#       'blobs_url': 'https://api.github.com/repos/dotnet/roslyn/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/dotnet/roslyn/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/dotnet/roslyn/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/dotnet/roslyn/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/dotnet/roslyn/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/dotnet/roslyn/languages',
#       'stargazers_url': 'https://api.github.com/repos/dotnet/roslyn/stargazers',
#       'contributors_url': 'https://api.github.com/repos/dotnet/roslyn/contributors',
#       'subscribers_url': 'https://api.github.com/repos/dotnet/roslyn/subscribers',
#       'subscription_url': 'https://api.github.com/repos/dotnet/roslyn/subscription',
#       'commits_url': 'https://api.github.com/repos/dotnet/roslyn/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/dotnet/roslyn/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/dotnet/roslyn/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/dotnet/roslyn/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/dotnet/roslyn/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/dotnet/roslyn/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/dotnet/roslyn/merges',
#       'archive_url': 'https://api.github.com/repos/dotnet/roslyn/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/dotnet/roslyn/downloads',
#       'issues_url': 'https://api.github.com/repos/dotnet/roslyn/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/dotnet/roslyn/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/dotnet/roslyn/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/dotnet/roslyn/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/dotnet/roslyn/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/dotnet/roslyn/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/dotnet/roslyn/deployments',
#       'created_at': '2015-01-11T02:39:03Z',
#       'updated_at': '2020-01-02T14:35:01Z',
#       'pushed_at': '2020-01-02T13:54:53Z',
#       'git_url': 'git://github.com/dotnet/roslyn.git',
#       'ssh_url': 'git@github.com:dotnet/roslyn.git',
#       'clone_url': 'https://github.com/dotnet/roslyn.git',
#       'svn_url': 'https://github.com/dotnet/roslyn',
#       'homepage': 'https://docs.microsoft.com/dotnet/csharp/roslyn-sdk/',
#       'size': 782637,
#       'stargazers_count': 12261,
#       'watchers_count': 12261,
#       'language': 'C#',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2849,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 6882,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 2849,
#       'open_issues': 6882,
#       'watchers': 12261,
#       'default_branch': 'master'}},
#     'base': {'label': 'Potapy4:master',
#      'ref': 'master',
#      'sha': 'fc8a3b823f9b436af78c05323e98d770ab77e9ce',
#      'user': {'login': 'Potapy4',
#       'id': 18706421,
#       'node_id': 'MDQ6VXNlcjE4NzA2NDIx',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/18706421?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Potapy4',
#       'html_url': 'https://github.com/Potapy4',
#       'followers_url': 'https://api.github.com/users/Potapy4/followers',
#       'following_url': 'https://api.github.com/users/Potapy4/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Potapy4/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Potapy4/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Potapy4/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Potapy4/orgs',
#       'repos_url': 'https://api.github.com/users/Potapy4/repos',
#       'events_url': 'https://api.github.com/users/Potapy4/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Potapy4/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 175951451,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNzU5NTE0NTE=',
#       'name': 'dotnet-roslyn',
#       'full_name': 'Potapy4/dotnet-roslyn',
#       'private': False,
#       'owner': {'login': 'Potapy4',
#        'id': 18706421,
#        'node_id': 'MDQ6VXNlcjE4NzA2NDIx',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/18706421?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Potapy4',
#        'html_url': 'https://github.com/Potapy4',
#        'followers_url': 'https://api.github.com/users/Potapy4/followers',
#        'following_url': 'https://api.github.com/users/Potapy4/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Potapy4/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Potapy4/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Potapy4/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Potapy4/orgs',
#        'repos_url': 'https://api.github.com/users/Potapy4/repos',
#        'events_url': 'https://api.github.com/users/Potapy4/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Potapy4/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Potapy4/dotnet-roslyn',
#       'description': 'The Roslyn .NET compiler provides C# and Visual Basic languages with rich code analysis APIs.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn',
#       'forks_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/forks',
#       'keys_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/teams',
#       'hooks_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/events',
#       'assignees_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/tags',
#       'blobs_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/languages',
#       'stargazers_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/subscription',
#       'commits_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/merges',
#       'archive_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/downloads',
#       'issues_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/deployments',
#       'created_at': '2019-03-16T09:23:54Z',
#       'updated_at': '2020-01-01T14:41:36Z',
#       'pushed_at': '2020-01-02T14:42:12Z',
#       'git_url': 'git://github.com/Potapy4/dotnet-roslyn.git',
#       'ssh_url': 'git@github.com:Potapy4/dotnet-roslyn.git',
#       'clone_url': 'https://github.com/Potapy4/dotnet-roslyn.git',
#       'svn_url': 'https://github.com/Potapy4/dotnet-roslyn',
#       'homepage': 'https://docs.microsoft.com/dotnet/csharp/roslyn-sdk/',
#       'size': 758926,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C#',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/pulls/1059'},
#      'html': {'href': 'https://github.com/Potapy4/dotnet-roslyn/pull/1059'},
#      'issue': {'href': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/issues/1059'},
#      'comments': {'href': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/issues/1059/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/pulls/1059/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/pulls/1059/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Potapy4/dotnet-roslyn/statuses/e0e7411e6be4ff65947fe08a8c537cc2388567cf'}},
#     'author_association': 'NONE',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 282,
#     'deletions': 1,
#     'changed_files': 5}},
#   'public': True,
#   'created_at': '2020-01-02T14:42:14Z'},
#  {'id': '11191117464',
#   'type': 'PushEvent',
#   'actor': {'id': 57451215,
#    'login': 'jinghuijuan6',
#    'display_login': 'jinghuijuan6',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jinghuijuan6',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57451215?'},
#   'repo': {'id': 220031410,
#    'name': 'jinghuijuan6/wodobango9300',
#    'url': 'https://api.github.com/repos/jinghuijuan6/wodobango9300'},
#   'payload': {'push_id': 4454090913,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '206009a111c372e542b13a09cc02420c0588f487',
#    'before': '87d0489480d623418a5c62c11991651e1b93a5fe',
#    'commits': [{'sha': '206009a111c372e542b13a09cc02420c0588f487',
#      'author': {'email': '18092748734@189.cn', 'name': 'jinghuijuan6'},
#      'message': 'log',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jinghuijuan6/wodobango9300/commits/206009a111c372e542b13a09cc02420c0588f487'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:14Z'},
#  {'id': '11191117457',
#   'type': 'PushEvent',
#   'actor': {'id': 33127894,
#    'login': 'GusSaalfeld',
#    'display_login': 'GusSaalfeld',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GusSaalfeld',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33127894?'},
#   'repo': {'id': 231114955,
#    'name': 'GusSaalfeld/MaGesture',
#    'url': 'https://api.github.com/repos/GusSaalfeld/MaGesture'},
#   'payload': {'push_id': 4454090902,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'acb48aeec7062c2a48d2d9b255f74cd1ff539e20',
#    'before': '40ef5ab5826fc71aa7f21f3181c686e219a043db',
#    'commits': [{'sha': 'acb48aeec7062c2a48d2d9b255f74cd1ff539e20',
#      'author': {'email': '33127894+GusSaalfeld@users.noreply.github.com',
#       'name': 'Gus Saalfeld'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/GusSaalfeld/MaGesture/commits/acb48aeec7062c2a48d2d9b255f74cd1ff539e20'}]},
#   'public': True,
#   'created_at': '2020-01-02T14:42:14Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests, json

r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'StationIdentifier': '2200H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 145.15},
#   {'StationIdentifier': '1730H070',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 226.25},
#   {'StationIdentifier': '1580H021',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 1.28},
#   {'StationIdentifier': '1580H017',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 25.73},
#   {'StationIdentifier': '2560H019',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 4.48},
#   {'StationIdentifier': '1580H001',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 224.21},
#   {'StationIdentifier': '1730H075',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 92.83},
#   {'StationIdentifier': '2420H036',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 164.37},
#   {'StationIdentifier': '2500H003',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 32.2},
#   {'StationIdentifier': '1730H066',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 138.73},
#   {'StationIdentifier': '1730H077',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 740.49},
#   {'StationIdentifier': '1550H014',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 26.75},
#   {'StationIdentifier': '1670H004',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 2.98},
#   {'StationIdentifier': '2420H019',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 109.97},
#   {'StationIdentifier': '1650H012',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.7},
#   {'StationIdentifier': '1730H061',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 266.23},
#   {'StationIdentifier': '1730H072',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 248.86},
#   {'StationIdentifier': '1540H039',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 38.99},
#   {'StationIdentifier': '1660H012',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.14},
#   {'StationIdentifier': '2370H025',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 261.61},
#   {'StationIdentifier': '1650H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.1},
#   {'StationIdentifier': '1730H057',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 43.48},
#   {'StationIdentifier': '1730H068',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 10.14},
#   {'StationIdentifier': '1540H037',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 32.01},
#   {'StationIdentifier': '1650H015',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.05},
#   {'StationIdentifier': '2370H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 124.1},
#   {'StationIdentifier': '1630H036',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 65.83},
#   {'StationIdentifier': '1660H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 4.85},
#   {'StationIdentifier': '1730H043',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 23.04},
#   {'StationIdentifier': '2420H043',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 79.32},
#   {'StationIdentifier': '1540H033',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 23.4},
#   {'StationIdentifier': '1650H010',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.19},
#   {'StationIdentifier': '1630H030',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 1.57},
#   {'StationIdentifier': '1630H032',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 0.13},
#   {'StationIdentifier': '1650H013',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 5.62},
#   {'StationIdentifier': '1680H005',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.11},
#   {'StationIdentifier': '2200H026',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 106.73},
#   {'StationIdentifier': '1350H031',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': -0.15},
#   {'StationIdentifier': '1630H040',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 1.76},
#   {'StationIdentifier': '1630H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 10.01},
#   {'StationIdentifier': '1630H027',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 26.14},
#   {'StationIdentifier': '1540H032',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 20.45},
#   {'StationIdentifier': '1550H012',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.54},
#   {'StationIdentifier': '1630H023',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.03},
#   {'StationIdentifier': '1350H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 175.97},
#   {'StationIdentifier': '1630H034',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 278.47},
#   {'StationIdentifier': '1590H016',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 11.27},
#   {'StationIdentifier': '1630H024',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 69.07},
#   {'StationIdentifier': '1540H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 13.13},
#   {'StationIdentifier': '1540H030',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 27.2},
#   {'StationIdentifier': '1630H005',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 39.76},
#   {'StationIdentifier': '1350H027',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 145.89},
#   {'StationIdentifier': '1510H082',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 752.39},
#   {'StationIdentifier': '1580H022',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.16},
#   {'StationIdentifier': '1430H054',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 48.29},
#   {'StationIdentifier': '1510H084',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 145.06},
#   {'StationIdentifier': '1540H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.59},
#   {'StationIdentifier': '1590H013',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 20.76},
#   {'StationIdentifier': '1510H080',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 1068.94},
#   {'StationIdentifier': '1510H058',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 12.13},
#   {'StationIdentifier': '1430H037',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 380.46},
#   {'StationIdentifier': '1430H051',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 95.66},
#   {'StationIdentifier': '1350H024',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 259.67},
#   {'StationIdentifier': '1520H008',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 78.22},
#   {'StationIdentifier': '1580H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 21.23},
#   {'StationIdentifier': '1510H079',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 187.7},
#   {'StationIdentifier': '1510H049',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 470.82},
#   {'StationIdentifier': '1430H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 50.6},
#   {'StationIdentifier': '1430H047',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 72.35},
#   {'StationIdentifier': '1350H020',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 220.79},
#   {'StationIdentifier': '1510H086',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 317.97},
#   {'StationIdentifier': '1580H008',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 19.39},
#   {'StationIdentifier': '1510H071',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 20.5},
#   {'StationIdentifier': '1430H056',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 79.83},
#   {'StationIdentifier': '1420H057',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 639.41},
#   {'StationIdentifier': '1420H058',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 440.47},
#   {'StationIdentifier': '1350H016',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 97.9},
#   {'StationIdentifier': '1550H017',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 15.74},
#   {'StationIdentifier': '1510H075',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 346.5},
#   {'StationIdentifier': '1430H045',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 91.76},
#   {'StationIdentifier': '1430H058',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 83.01},
#   {'StationIdentifier': '1400H015',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 622.43},
#   {'StationIdentifier': '1420H055',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 318.68},
#   {'StationIdentifier': '1340H015',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 50.08},
#   {'StationIdentifier': '1420H054',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 704.2},
#   {'StationIdentifier': '1350H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 282.05},
#   {'StationIdentifier': '1430H040',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 19.29},
#   {'StationIdentifier': '1340H014',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.37},
#   {'StationIdentifier': '1400H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 191.55},
#   {'StationIdentifier': '1140H106',
#    'RecordTime': 'Dec 11, 2019 2:55:00 PM',
#    'WaterLevel': 49.11},
#   {'StationIdentifier': '2370H017',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 58.49},
#   {'StationIdentifier': '1420H049',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 54.19},
#   {'StationIdentifier': '1350H001',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 169.81},
#   {'StationIdentifier': '1300H022',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': -1.01},
#   {'StationIdentifier': '1340H011',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 7.38},
#   {'StationIdentifier': '1140H108',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 12.12},
#   {'StationIdentifier': '1140H099',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 263.49},
#   {'StationIdentifier': '1850H005',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 22.09},
#   {'StationIdentifier': '1400H019',
#    'RecordTime': 'Dec 11, 2019 2:40:00 PM',
#    'WaterLevel': 310.14},
#   {'StationIdentifier': '1290H002',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 41}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
