# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url='https://www.ptt.cc/bbs/NBA/index.html'
headers={'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36'}
r=requests.get(url, headers=headers)
sp=BeautifulSoup(r.text, 'html.parser')
newauthor=sp.find(class_='author').text
newtitle=sp.find(class_='title').text
newdate=sp.find(class_='date').text
print(newauthor, newtitle, newdate)
# Out:
# ljislovej
# Re: [討論] 上一個和Zion一樣強的狀元大概是什麼時候
#   2/14

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
for d in sp.find_all(class_='r-ent'):
    allauthor=d.find(class_='author').text
    alltitle=d.find(class_='title').text
    alldate=d.find(class_='date').text
    print(' 作者：',allauthor,'\n','標題：',alltitle.replace('\n','').replace('\t',''),'\n','時間：',alldate,'\n')
# Out:
#  作者： ljislovej
#  標題： Re: [討論] 上一個和Zion一樣強的狀元大概是什麼時候
#  時間：  2/14
#
#  作者： bailanchi
#  標題： [討論] 聯盟近年來是不是沒有正義之師了？
#  時間：  2/14
#
#  作者： s27052705
#  標題： [新聞] 史上最貴籃球球員卡！　喬丹、詹姆斯雙L
#  時間：  2/14
#
#  作者： Gotham
#  標題： [新聞] 明星賽前奪冠賠率 洛城雙雄、公鹿領先群雄
#  時間：  2/14
#
#  作者： currykukuo
#  標題： [花邊] Lue憶16奪冠：LBJ說他保證贏下搶七，全隊為此而瘋狂
#  時間：  2/15
#
#  作者： misomochi
#  標題： Re: [討論] 上一個和Zion一樣強的狀元大概是什麼時候
#  時間：  2/15
#
#  作者： Vedan
#  標題： [公告] 板規v6.8
#  時間：  5/24
#
#  作者： Vedan
#  標題： [公告] 樂透取消及未來不再開啟樂透
#  時間：  6/24
#
#  作者： qazwsx879345
#  標題： [公告] 版主上任相關事項
#  時間： 10/25
#
#  作者： Acetoxy
#  標題： [情報] SEASON Schedule 賽程 February 19–20
#  時間：  1/31

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
for i in range(13,18):
    url='https://www.ptt.cc/bbs/Baseball/index100%s.html' % str(i)
    headers={'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36'}
    r=requests.get(url, headers=headers)
    sp=BeautifulSoup(r.text, 'html.parser')
    for d in sp.find_all(class_='r-ent'):
        allauthor=d.find(class_='author').text
        alltitle=d.find(class_='title').text
        alldate=d.find(class_='date').text
        print(' 作者：',allauthor,'\n','標題：',alltitle.replace('\n','').replace('\t',''),'\n','時間：',alldate,'\n')
# Out:
#  作者： AisinGioro
#  標題： Re: [新聞] 張志豪提薪資仲裁　劉志威：靜待結果
#  時間：  2/11
#
#  作者： Paul1021
#  標題： Re: [賽程] 2020中華職棒31年 上半季賽程表
#  時間：  2/11
#
#  作者： kenbo
#  標題： [新聞] 6搶1／名單增至26人 台荷澳與中職打七場
#  時間：  2/11
#
#  作者： zzyyxx77
#  標題： [新聞] CJS薪資談不攏撕破臉 中信兄弟張志豪提出
#  時間：  2/11
#
#  作者： Intelnet
#  標題： [新聞] 野村親自來台測試 吳俊良被時代擋下旅日夢
#  時間：  2/11
#
#  作者： assnccu8787
#  標題： Re: [新聞] CJS-中職公布今年賽程 比賽球場愈來
#  時間：  2/11
#
#  作者： saiulbb
#  標題： [新聞] MLB》Betts降臨洛城！誰是下一名足以影響聯盟版圖的男主角？
#  時間：  2/11
#
#  作者： saiulbb
#  標題： [新聞] 【李秉昇 MLB專欄】大聯盟提新季後賽制 利多於弊值得期待
#  時間：  2/11
#
#  作者： what62651
#  標題： [新聞] 達比修發文追悼野村過世 感謝他「救命之
#  時間：  2/11
#
#  作者： what62651
#  標題： [新聞] SPC-「野球人生最大幸運」 田中將大悼恩
#  時間：  2/11
#
#  作者： johnson20524
#  標題： [新聞] 大聯盟想改季後賽賽制　鮑爾開嗆主席
#  時間：  2/11
#
#  作者： hvariables
#  標題： [新聞] 中職／張志豪薪資持續溝通 拚仲裁前達共識
#  時間：  2/11
#
#  作者： cena0605
#  標題： [閒聊] 王柏融春訓表現 日文討論區
#  時間：  2/11
#
#  作者： pp5434
#  標題： Re: [新聞] 野村克也過世
#  時間：  2/11
#
#  作者： Intelnet
#  標題： [新聞] SPC-南韓潛水艇朴鐘勳  也想挑戰大聯盟
#  時間：  2/11
#
#  作者： currykukuo
#  標題： [新聞] SPC-李茲為何不來了 韓國網友竟一面倒猜是這原因
#  時間：  2/11
#
#  作者： u10400068
#  標題： [討論] 日職上古神獸沒那麼老害的有誰?
#  時間：  2/11
#
#  作者： thnlkj0665
#  標題： [分享] 田口麗斗 今天練投146球
#  時間：  2/11
#
#  作者： u9300017
#  標題： [新聞] 爭一軍出賽空間　申皓瑋起步完整春訓
#  時間：  2/11
#
#  作者： cena0605
#  標題： [閒聊] 阿部這樣訓練有什麼意義嗎？！
#  時間：  2/11
#
#  作者： thnlkj0665
#  標題： [分享] 阪神隊 一日隊長特別款球衣
#  時間：  2/11
#
#  作者： pp5434
#  標題： [討論] 2010-2019的軟銀 V.S.1982-1992的西武
#  時間：  2/11
#
#  作者： zaxs
#  標題： [新聞] 陳柏毓僅投3局奪7K 預賽第二日10隊2連勝
#  時間：  2/11
#
#  作者： zaxs
#  標題： [新聞] 6搶1中華隊新LOGO A款得票不到9000票勝出
#  時間：  2/11
#
#  作者： barry610171
#  標題： Re: [新聞] 練游擊非玩笑 鄭鎧文：外野變生疏
#  時間：  2/11
#
#  作者： gify0712
#  標題： [分享] 日職神獸披頭四
#  時間：  2/12
#
#  作者： bower1025
#  標題： Re: [新聞] 練游擊非玩笑 鄭鎧文：外野變生疏
#  時間：  2/12
#
#  作者： alwu
#  標題： [分享] 軟銀球春分享
#  時間：  2/12
#
#  作者： waitan
#  標題： Re: [討論] 棒球大聯盟跟鑽石王牌那個比較好看？
#  時間：  2/12
#
#  作者： arashicool
#  標題： [公告] 水桶公告
#  時間：  2/12
#
#  作者： Kyosuke
#  標題： [閒聊] 最好的 "職業棒球" 生涯 - 悼 野村克也
#  時間：  2/12
#
#  作者： hicker
#  標題： [LIVE] 108學年度高中聯賽木棒組 2/12賽程
#  時間：  2/12
#
#  作者： CTBA
#  標題： [閒聊] 教士隊不戴納粹帽 改回原來的 "欸思滴"
#  時間：  2/12
#
#  作者： shiaubai
#  標題： [新聞] 全隊最會轟 神全曝秘密菜單
#  時間：  2/12
#
#  作者： shiaubai
#  標題： [新聞] 腰傷拖累成績 高國輝補好補滿
#  時間：  2/12
#
#  作者： wwf0322
#  標題： [新聞] 王建民擔任餵球投手 兄弟球員「圓夢」啦
#  時間：  2/12
#
#  作者： beautyptt
#  標題： [新聞] 開訓展「大」志 殷仔明穿「水手服」
#  時間：  2/12
#
#  作者： -
#  標題： (已被arashicool刪除) <a000209898>B-2
#  時間：  2/12
#
#  作者： shiaubai
#  標題： [新聞] 新招式不夠殺 王正棠換舊招
#  時間：  2/12
#
#  作者： currykukuo
#  標題： [新聞] 中職／回鍋洋將有好有壞 桃猿眼光最精準
#  時間：  2/12
#
#  作者： currykukuo
#  標題： [新聞] 去年轟吳昇峰讓台灣心碎 若克今預約大聯盟
#  時間：  2/12
#
#  作者： olmtw
#  標題： [新聞] MLB／投手大谷趕不上開季 二刀流要等5月
#  時間：  2/12
#
#  作者： currykukuo
#  標題： [新聞] 扮演太空人偷暗號要角 貝爾川被隊友暱稱教父
#  時間：  2/12
#
#  作者： mongi
#  標題： [新聞] CJS 中職賽程公布一半 史上第2次
#  時間：  2/12
#
#  作者： jhemezuo
#  標題： [新聞] 甜美女星浜辺美波送手作巧克力　佐佐木朗
#  時間：  2/12
#
#  作者： polanco
#  標題： [新聞] 大谷歸隊時間延後　天使說明原因
#  時間：  2/12
#
#  作者： barry610171
#  標題： [討論] 球員都會怎麼看待玩壞的教練？
#  時間：  2/12
#
#  作者： Ulysses
#  標題： [閒聊] 琉球藍海隊2/14將舉行球員入團記者會
#  時間：  2/12
#
#  作者： polanco
#  標題： [新聞] 2017年參與偷暗號　前太空人球員岡薩雷
#  時間：  2/12
#
#  作者： Wojnarowski
#  標題： [新聞] 肺炎疫情影響　統一獅赴日交流賽取消
#  時間：  2/12
#
#  作者： Sky77777777
#  標題： [新聞] 砰砰砰！道歉了　岡薩雷茲成首位太空人作
#  時間：  2/12
#
#  作者： -
#  標題： (本文已被刪除) <whj0530>
#  時間：  2/12
#
#  作者： hvariables
#  標題： [新聞] 大聯盟搶救票房 讓季後賽變好玩
#  時間：  2/12
#
#  作者： Wojnarowski
#  標題： [新聞] 統一獅日本行喊卡　全隊移師花蓮春訓
#  時間：  2/12
#
#  作者： polanco
#  標題： [新聞] 等不到官方回覆 紅襪開訓宣布羅尼克代理
#  時間：  2/12
#
#  作者： anzepam
#  標題： [討論] 一個被演藝圈耽誤的棒球偶像：龜梨和也
#  時間：  2/12
#
#  作者： johnson20524
#  標題： [新聞] 只有1%機會也不放棄 陳偉殷感謝水手給機
#  時間：  2/12
#
#  作者： golover
#  標題： [新聞] SPC 塞內角砸到王柏融 阪神右投自認投
#  時間：  2/12
#
#  作者： u9300017
#  標題： [新聞] 統一獅前進花蓮移訓　熱身賽開放球迷進場
#  時間：  2/12
#
#  作者： Intelnet
#  標題： [新聞] 年底挑戰大聯盟?英雄金河成從高雄春訓出發
#  時間：  2/12
#
#  作者： www90173
#  標題： [閒聊] 張志豪為何薪資談不好也不宣告自由球員
#  時間：  2/12
#
#  作者： Intelnet
#  標題： [新聞] 昔日洛磯40轟重砲 岡薩雷茲加盟水手
#  時間：  2/12
#
#  作者： ccpz
#  標題： Re: [新聞] 砰砰砰！道歉了　岡薩雷茲成首位太空人作
#  時間：  2/12
#
#  作者： bearhead
#  標題： [分享] 劉致榮搞笑
#  時間：  2/12
#
#  作者： BBMADE
#  標題： [新聞] SPC-MLB》大都會花17.2億整修春訓基地 卻
#  時間：  2/12
#
#  作者： Intelnet
#  標題： [新聞] 野村克也生前最後一次專訪 為職棒未來憂心
#  時間：  2/12
#
#  作者： assnccu8787
#  標題： Re: [閒聊] 張志豪為何薪資談不好也不宣告自由球員
#  時間：  2/12
#
#  作者： BBMADE
#  標題： [新聞] 中職／ 張志豪提仲裁 近3例都是兄弟球員
#  時間：  2/12
#
#  作者： Allen524
#  標題： Re: [閒聊] 張志豪為何薪資談不好也不宣告自由球員
#  時間：  2/12
#
#  作者： VVizZ
#  標題： Re: [閒聊] 張志豪為何薪資談不好也不宣告自由球員
#  時間：  2/12
#
#  作者： swordxia
#  標題： [新聞] 消失的龍捲風　林昱珉好球率倍增飆11K
#  時間：  2/12
#
#  作者： mongi
#  標題： [新聞] 高雄漢神百貨進軍中台灣 打造台中洲際娛
#  時間：  2/12
#
#  作者： jack801016
#  標題： Re: [分享] 2020MLB轉播MOD的民視無線台也看得到
#  時間：  2/12
#
#  作者： zaxs
#  標題： [新聞] 野村克也ID野球攻略法　曾讓打擊之神一朗
#  時間：  2/12
#
#  作者： zaxs
#  標題： [新聞] WZH-連3年20轟  中信兄弟張志豪提出仲裁為
#  時間：  2/12
#
#  作者： thnlkj0665
#  標題： [新聞] 寶貴的「第2次機會」林政賢收起嬉皮笑臉珍惜舞台
#  時間：  2/12
#
#  作者： currykukuo
#  標題： [新聞] 與陳大豐不合 野村克也曾怒批：聽不懂日文嗎
#  時間：  2/12
#
#  作者： ihcc
#  標題： [分享] 原辰德「龜井是重要的選手」
#  時間：  2/12
#
#  作者： u9300017
#  標題： [新聞] 統一紅白戰鄭鎧文守游擊　江辰晏施子謙
#  時間：  2/12
#
#  作者： barry610171
#  標題： Re: [閒聊] 張志豪為何薪資談不好也不宣告自由球員
#  時間：  2/12
#
#  作者： saiulbb
#  標題： [新聞] 【李秉昇 MLB專欄】送走Betts罪不可赦？ 紅襪沒有對不起襪迷
#  時間：  2/12
#
#  作者： saiulbb
#  標題： [新聞] MLB／羅德里奎茲投出生涯年 與紅襪打薪資仲裁
#  時間：  2/12
#
#  作者： saiulbb
#  標題： [新聞] MLB》Maddon分手小熊背後原因 管理階層想掌控一切
#  時間：  2/12
#
#  作者： LinBaoYan
#  標題： [新聞] 回顧日職生涯首年 王柏融：「不管好與不好都是突破的方向」
#  時間：  2/12
#
#  作者： u9300017
#  標題： [新聞] 5隊共識打滿二軍場次　採用雙重賽7局制
#  時間：  2/12
#
#  作者： pp5434
#  標題： Re: [新聞] 統一紅白戰鄭鎧文守游擊　江辰晏施子謙
#  時間：  2/12
#
#  作者： mongi
#  標題： [新聞] 同球隊第二指名進職棒 徐若熙、廖文揚
#  時間：  2/12
#
#  作者： Amygo
#  標題： [討論] 野村為何對大豐有偏見?
#  時間：  2/12
#
#  作者： u9300017
#  標題： [新聞] 最在乎全勤出賽　蘇智傑今年挑戰最年輕
#  時間：  2/12
#
#  作者： thnlkj0665
#  標題： [分享] 羅德隊 公布那霸遠征名單
#  時間：  2/12
#
#  作者： polanco
#  標題： [新聞] SPC 不行了？大聯盟最新戰力榜 克蕭、怪
#  時間：  2/12
#
#  作者： gogoto990
#  標題： [閒聊] 張志豪與藍寅倫
#  時間：  2/12
#
#  作者： hvariables
#  標題： [新聞] 中職》擺脫去年低潮 郭阜林改善打擊重心
#  時間：  2/12
#
#  作者： golover
#  標題： [新聞] 林煜清轉隊後首度實戰 今年角色為長中繼
#  時間：  2/12
#
#  作者： rainfruit
#  標題： Re: [閒聊] 阿部這樣訓練有什麼意義嗎？！
#  時間：  2/12
#
#  作者： jackwelch
#  標題： Re: [閒聊] 阿部這樣訓練有什麼意義嗎？！
#  時間：  2/12
#
#  作者： jumpballfan
#  標題： [討論] 整天酸小玉,那比小玉強的中職打者有誰?
#  時間：  2/12
#
#  作者： assnccu8787
#  標題： [閒聊] 志豪假如在味全能拿多少錢?
#  時間：  2/12
#
#  作者： bower1025
#  標題： Re: [討論]整天酸小玉,那比小玉強的中職打者有誰?
#  時間：  2/12
#
#  作者： sukiyasuica
#  標題： [新聞] SPC-日職》驚！王柏融前打擊教練 春訓遭
#  時間：  2/12
